# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/tech_mental_health_burnout.csv")

# %%
df
# Out:
#         age      gender            job_role  experience_years company_size  \
# 0        50      Female   Backend Developer               7.8        Large
# 1        36        Male  Frontend Developer               1.8     Mid-size
# 2        29        Male              DevOps               2.5          MNC
# 3        42      Female   Backend Developer               1.5     Mid-size
# 4        40      Female  Frontend Developer               3.4        Large
# ...     ...         ...                 ...               ...          ...
# 149995   54      Female              DevOps               6.8     Mid-size
# 149996   52        Male   Software Engineer               5.7      Startup
# 149997   36        Male   Backend Developer               2.2     Mid-size
# 149998   35        Male  Frontend Developer               3.7        Large
# 149999   36  Non-binary              DevOps               5.0     Mid-size
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   age                      150000 non-null  int64
#  1   gender                   150000 non-null  object
#  2   job_role                 150000 non-null  object
#  3   experience_years         150000 non-null  float64
#  4   company_size             150000 non-null  object
#  5   work_mode                150000 non-null  object
#  6   work_hours_per_week      150000 non-null  float64
#  7   overtime_hours           150000 non-null  float64
#  8   meetings_per_day         150000 non-null  float64
#  9   deadlines_missed         150000 non-null  int64
#  10  job_satisfaction         150000 non-null  float64
#  11  manager_support          150000 non-null  float64
#  12  work_life_balance        150000 non-null  float64
# ...
